# %%
import IPython.display as display
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os
import torch
from torch.utils import data

import numpy as np
import matplotlib.pyplot as plt
from transferlearningmodel import Net
from DataLoader import Dataset
from sklearn.model_selection import train_test_split

import torch
from torch import nn
import torchvision
import torchvision.transforms as transform

from sklearn.model_selection import train_test_split

import tensorflow as tf
from PIL import Image
import numpy as np
import cv2
import glob
import time

from PIL import Image
import os.path

import numpy as np
import matplotlib.pyplot as plt
from transferlearningmodel import Net
from DataLoader import Dataset
from sklearn.model_selection import train_test_split

import torch
from torch import nn
import torchvision
import torchvision.transforms as transform
from torch.utils.data.sampler import SubsetRandomSampler
# Out:
# /anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
from torchvision.utils import make_grid
import time

# %%
from skimage import io
import pandas as pd
from torch.utils.data import Dataset, DataLoader,random_split

# %%
pd.read_csv('train.csv')
# Out:
#       Unnamed: 0  Unnamed: 0.1                  img_name          category  \
# 0              0          2274  SOB_B_TA_14-21978AB_200X   tubular_adenoma
# 1              1           595     SOB_M_DC_14-4372_400X  ductal_carcinoma
# 2              2          1982    SOB_B_TA_14-16184_100X   tubular_adenoma
# 3              3          3706  SOB_B_PT_14-21998AB_400X   phyllodes_tumor
# 4              4           371     SOB_M_DC_14-15792_40X  ductal_carcinoma
# ...          ...           ...                       ...               ...
# 2324        2324          2570     SOB_B_F_14-14134_100X      fibroadenoma
# 2325        2325          3249   SOB_B_F_14-21998EF_200X      fibroadenoma
# 2326        2326           332    SOB_M_DC_14-12312_200X  ductal_carcinoma
# 2327        2327          1568    SOB_B_A_14-22549G_400X          adenosis
# 2328        2328          2019     SOB_B_TA_14-16184_40X   tubular_adenoma
#
#       binary img_size  label  \
# 0          0     200X   2274
# 1          1     400X    595
# 2          0     100X   1982
# 3          0     400X   3706
# 4          1      40X    371
# ...      ...      ...    ...
# 2324       0     100X   2570
# 2325       0     200X   3249
# 2326       1     200X    332
# 2327       0     400X   1568
# 2328       0      40X   2019
#
#                                               full_path
# 0     /Users/yingyinxiao/breast_cancer/data/benign/t...
# 1     /Users/yingyinxiao/breast_cancer/data/malignan...
# 2     /Users/yingyinxiao/breast_cancer/data/benign/t...
# 3     /Users/yingyinxiao/breast_cancer/data/benign/p...
# 4     /Users/yingyinxiao/breast_cancer/data/malignan...
# ...                                                 ...
# 2324  /Users/yingyinxiao/breast_cancer/data/benign/f...
# 2325  /Users/yingyinxiao/breast_cancer/data/benign/f...
# 2326  /Users/yingyinxiao/breast_cancer/data/malignan...
# 2327  /Users/yingyinxiao/breast_cancer/data/benign/a...
# 2328  /Users/yingyinxiao/breast_cancer/data/benign/t...
#
# [2329 rows x 8 columns]

# %%
class Dataset(data.Dataset):
    """
    Args:
        csv_file (string): Path to the csv file with annotations.
        root_dir (string): Directory with all the images.
        transform (callable, optional): Optional transform to be applied
            on a sample.
    """
    def __init__(self, csv_file, transform = None):
        'Initialization'
        self.frame = pd.read_csv(csv_file)
        self.transform = transform

    def __len__(self):
        'Denotes the total number of samples'
        return len(self.frame)

    def __getitem__(self, index):
        'Generates one sample of data'
        # Select sample
        img_name = self.frame.iloc[index, 6]
        image = io.imread(img_name)
        
        PIL_image = Image.fromarray(image)
        
        label = self.frame.iloc[index, 3]
        # Load data and get label
        
        if self.transform:
            image = self.transform(PIL_image)
            
        return image, label

# %%
def train_model(train_loader, val_loader):

    # Define relevant testing parameters - the loss per iteration/epoch for training
    # and validation sets
    train_loss_per_iter = []
    train_epoch_loss = []
    val_loss_per_iter = []
    val_epoch_loss = []
    val_epoch_acc = []

    # Define the cnn model
    model = Net()

    # Define the cost function
    criterion = nn.BCELoss()

    # Define the optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr = 1e-3)

    best_val_loss = float('inf') 
    # hold off on variable for now (use this to check if the model loss is increasing x number of times)

    # Runs through one batch in the train_loader
    n_epoch = 10
    
    for epoch in range(n_epoch):
        print("epoch: ", epoch)
        # Define variables to accumulate the loss over the total epoch
        train_epoch_loss_var = 0
        val_epoch_loss_var = 0

        # This for loop is for the training set data
        # ********** Coordinate with the dataloader *************
        # this for loops is looking for a tuple(?) of images and labels
#         for imgs, (_, labels) in train_loader:
        for i, (imgs,labels) in enumerate(train_loader):
        
            print("minibatch: ", i, " out of ", len(train_loader))
            
            labels = labels.view(labels.size(0), 1)
            # Zeroes the gradients so they don't accumulate
            optimizer.zero_grad()

            # Pass one image forward through the cnn
            outputs = model(imgs)

            # Assigns the loss function to the outputs
            loss = criterion(outputs, labels.float())
#             clear(outputs)

            # Computes the gradients with respect to the cost function
            loss.backward()

            # Move in the direction of gradient descent
            optimizer.step()

            train_loss_per_iter.append(loss)
            train_epoch_loss_var += loss
            
            print("loss: ", loss)


        # This for loop is for the validation set data
        for  i, (imgs,labels) in enumerate(val_loader):
            
            labels = labels.view(labels.size(0), 1)
            # Pass one image forward through the cnn
            outputs = model(imgs)

            # Assigns the loss function to the outputs
            loss = criterion(outputs, labels.float())

            # Save loss per iteration
            val_loss_per_iter.append(loss)
            val_epoch_loss_var += loss

        # Save values of loss over total epoch
        train_epoch_loss.append(train_epoch_loss_var)
        val_epoch_loss.append(val_epoch_loss_var)
    
    torch.save(model, 'saved_model.pt')
    
    return  train_loss_per_iter, train_epoch_loss, val_loss_per_iter, val_epoch_loss, val_epoch_acc

# %%
trainingSet = Dataset(csv_file = 'train.csv')
validationSet = Dataset(csv_file = 'val.csv')
testSet = Dataset(csv_file = 'test.csv')

# %%
trainLoader = torch.utils.data.DataLoader(trainingSet, batch_size = 2)
validationLoader = torch.utils.data.DataLoader(validationSet, batch_size = 2)
testLoader = torch.utils.data.DataLoader(testSet, batch_size = 2)

# %%
# train_model(trainLoader, validationLoader)

# %%
# pd.read_csv('csv.csv')

# %%
# dataset = Dataset(csv_file = 'csv.csv', \
#                  transform = transform.Compose([transform.Resize((100,100)), \
#                                                 transform.ToTensor(),\
#                                                transform.Normalize((0.5, 0.5, 0.5), \
#                                                                     (0.5, 0.5, 0.5))]))
# dataset.__getitem__(0)

# %%
a= len(pd.read_csv('csv.csv'))
indices
# Out:
# [3,
#  1604,
#  678,
#  797,
#  1440,
#  3364,
#  1996,
#  870,
#  2421,
#  2905,
#  2986,
#  654,
#  273,
#  2862,
#  1020,
#  3300,
#  822,
#  1231,
#  249,
#  1619,
#  3276,
#  833,
#  422,
#  116,
#  3177,
#  360,
#  653,
#  1483,
#  3397,
#  40,
#  3797,
#  2825,
#  1130,
#  1217,
#  3604,
#  791,
#  3049,
#  3222,
#  2890,
#  271,
#  3443,
#  3131,
#  715,
#  2145,
#  1235,
#  3554,
#  1742,
#  1163,
#  390,
#  3092,
#  3477,
#  718,
#  743,
#  3089,
#  716,
#  3602,
#  1378,
#  2919,
#  1477,
#  3680,
#  3299,
#  2974,
#  2982,
#  681,
#  17,
#  3318,
#  1916,
#  2187,
#  150,
#  1671,
#  224,
#  324,
#  1207,
#  724,
#  3337,
#  2707,
#  2333,
#  2728,
#  3328,
#  3128,
#  2718,
#  2881,
#  2499,
#  927,
#  3710,
#  3748,
#  2678,
#  2683,
#  398,
#  2992,
#  1285,
#  2025,
#  2689,
#  2138,
#  1101,
#  466,
#  3165,
#  1613,
#  785,
#  3101,
#  1650,
#  2839,
#  3859,
#  144,
#  1727,
#  1659,
#  109,
#  505,
#  2664,
#  2516,
#  2559,
#  2232,
#  579,
#  3340,
#  1592,
#  3158,
#  655,
#  1642,
#  1941,
#  3011,
#  2723,
#  178,
#  3268,
#  565,
#  768,
#  2698,
#  2474,
#  1150,
#  695,
#  1182,
#  2262,
#  1330,
#  3744,
#  72,
#  177,
#  2437,
#  2099,
#  1143,
#  1136,
#  2597,
#  1784,
#  867,
#  957,
#  3095,
#  1370,
#  1430,
#  245,
#  3118,
#  806,
#  1978,
#  2518,
#  3777,
#  3007,
#  1405,
#  2688,
#  143,
#  2912,
#  3226,
#  2953,
#  1505,
#  694,
#  2331,
#  411,
#  1833,
#  2146,
#  171,
#  3051,
#  2264,
#  2933,
#  2733,
#  679,
#  554,
#  1284,
#  237,
#  90,
#  2248,
#  1950,
#  3839,
#  1955,
#  1626,
#  1294,
#  2739,
#  590,
#  3546,
#  269,
#  710,
#  332,
#  2709,
#  485,
#  1227,
#  2326,
#  49,
#  2247,
#  425,
#  3020,
#  713,
#  3709,
#  79,
#  1548,
#  1017,
#  1828,
#  1218,
#  2947,
#  329,
#  624,
#  2821,
#  2564,
#  1418,
#  66,
#  3654,
#  3811,
#  1902,
#  36,
#  714,
#  2466,
#  2744,
#  652,
#  3761,
#  1620,
#  1872,
#  2351,
#  3229,
#  3742,
#  1353,
#  1481,
#  1071,
#  702,
#  3704,
#  561,
#  922,
#  1389,
#  374,
#  2475,
#  1617,
#  3493,
#  246,
#  1401,
#  137,
#  751,
#  2655,
#  1576,
#  1756,
#  1408,
#  2835,
#  944,
#  2783,
#  1226,
#  972,
#  607,
#  2697,
#  1826,
#  1475,
#  2202,
#  2398,
#  1291,
#  2918,
#  728,
#  1066,
#  3879,
#  2750,
#  2217,
#  2494,
#  3347,
#  3796,
#  3733,
#  3603,
#  1202,
#  2691,
#  1496,
#  514,
#  1834,
#  3643,
#  128,
#  2834,
#  449,
#  708,
#  68,
#  1013,
#  1878,
#  1929,
#  495,
#  1816,
#  1113,
#  1729,
#  105,
#  77,
#  1211,
#  1795,
#  3717,
#  583,
#  183,
#  2773,
#  642,
#  3152,
#  2592,
#  3860,
#  1536,
#  587,
#  3598,
#  114,
#  2654,
#  879,
#  2432,
#  1407,
#  3585,
#  597,
#  1469,
#  1894,
#  3336,
#  3200,
#  1904,
#  3310,
#  1541,
#  3495,
#  2046,
#  230,
#  3826,
#  1470,
#  1223,
#  849,
#  2065,
#  1005,
#  3673,
#  3424,
#  1184,
#  134,
#  740,
#  3309,
#  3029,
#  2115,
#  1173,
#  999,
#  2971,
#  919,
#  3786,
#  408,
#  1003,
#  848,
#  3779,
#  359,
#  3771,
#  453,
#  1577,
#  3207,
#  1840,
#  3612,
#  3259,
#  1038,
#  2346,
#  108,
#  720,
#  3700,
#  2996,
#  2060,
#  3253,
#  3124,
#  527,
#  1933,
#  1301,
#  2208,
#  2412,
#  539,
#  2204,
#  1086,
#  148,
#  692,
#  247,
#  2800,
#  3272,
#  174,
#  3727,
#  3642,
#  1164,
#  1062,
#  954,
#  1785,
#  523,
#  3362,
#  244,
#  2448,
#  2576,
#  3882,
#  2729,
#  1641,
#  633,
#  479,
#  433,
#  2644,
#  1895,
#  2573,
#  254,
#  3485,
#  1041,
#  1342,
#  3584,
#  2856,
#  1424,
#  1001,
#  1266,
#  856,
#  3105,
#  3446,
#  445,
#  1747,
#  745,
#  3651,
#  127,
#  2193,
#  3619,
#  283,
#  3526,
#  2077,
#  366,
#  1745,
#  1047,
#  1603,
#  2098,
#  467,
#  1492,
#  2323,
#  1509,
#  2242,
#  794,
#  1993,
#  3031,
#  1500,
#  2127,
#  838,
#  1741,
#  3027,
#  959,
#  2175,
#  3428,
#  1248,
#  3498,
#  2589,
#  2913,
#  2386,
#  511,
#  1383,
#  1853,
#  255,
#  3829,
#  1669,
#  2824,
#  2943,
#  2163,
#  2639,
#  3711,
#  596,
#  2631,
#  3046,
#  3290,
#  717,
#  1295,
#  2345,
#  914,
#  853,
#  510,
#  1540,
#  2453,
#  3122,
#  480,
#  2249,
#  3068,
#  1032,
#  2802,
#  1794,
#  2833,
#  3757,
#  869,
#  1437,
#  601,
#  1780,
#  2841,
#  985,
#  3212,
#  3430,
#  2251,
#  2391,
#  1865,
#  3671,
#  2241,
#  1138,
#  1454,
#  3368,
#  3499,
#  2111,
#  748,
#  2223,
#  1811,
#  2431,
#  548,
#  2621,
#  3323,
#  2651,
#  2030,
#  3069,
#  3586,
#  61,
#  198,
#  2439,
#  2769,
#  2314,
#  2748,
#  16,
#  632,
#  3348,
#  430,
#  566,
#  2962,
#  2909,
#  2886,
#  3522,
#  2998,
#  2803,
#  2048,
#  1257,
#  3793,
#  3191,
#  2245,
#  3145,
#  3540,
#  3469,
#  0,
#  1394,
#  1971,
#  810,
#  2551,
#  2656,
#  2301,
#  1459,
#  1043,
#  2365,
#  1293,
#  7,
#  2150,
#  2489,
#  121,
#  276,
#  4,
#  3509,
#  2600,
#  197,
#  535,
#  3508,
#  3343,
#  3684,
#  854,
#  2050,
#  3476,
#  9,
#  1297,
#  1176,
#  1685,
#  602,
#  1372,
#  2102,
#  2696,
#  890,
#  3530,
#  1898,
#  2726,
#  2776,
#  1649,
#  2801,
#  2389,
#  434,
#  3759,
#  3556,
#  3547,
#  2246,
#  1346,
#  3009,
#  456,
#  2126,
#  902,
#  403,
#  2159,
#  2713,
#  1514,
#  1859,
#  3531,
#  328,
#  339,
#  3702,
#  611,
#  3228,
#  3828,
#  1900,
#  1802,
#  2024,
#  880,
#  1502,
#  3510,
#  436,
#  3324,
#  938,
#  2981,
#  3436,
#  1200,
#  703,
#  2313,
#  2036,
#  1994,
#  2926,
#  1546,
#  1862,
#  3701,
#  1410,
#  2815,
#  2819,
#  2795,
#  3863,
#  1316,
#  2119,
#  2887,
#  1429,
#  3869,
#  354,
#  440,
#  346,
#  153,
#  2944,
#  126,
#  977,
#  1809,
#  2151,
#  2791,
#  2316,
#  34,
#  2040,
#  314,
#  1046,
#  2714,
#  2312,
#  1646,
#  3440,
#  2970,
#  3396,
#  3320,
#  3332,
#  2154,
#  3419,
#  2426,
#  1337,
#  3001,
#  1686,
#  3366,
#  2904,
#  1037,
#  1844,
#  2165,
#  1320,
#  13,
#  1449,
#  431,
#  3621,
#  892,
#  531,
#  3034,
#  3665,
#  1239,
#  2694,
#  1432,
#  3681,
#  3263,
#  42,
#  1442,
#  2637,
#  3548,
#  2268,
#  2161,
#  2471,
#  3699,
#  2181,
#  3183,
#  802,
#  1417,
#  1082,
#  1400,
#  75,
#  1719,
#  896,
#  367,
#  3173,
#  1981,
#  1355,
#  1050,
#  2640,
#  1111,
#  3062,
#  2338,
#  2122,
#  181,
#  2092,
#  1652,
#  155,
#  3721,
#  1954,
#  3344,
#  627,
#  297,
#  3269,
#  639,
#  1639,
#  1787,
#  308,
#  3108,
#  2997,
#  131,
#  113,
#  1340,
#  3851,
#  1124,
#  118,
#  1887,
#  33,
#  542,
#  337,
#  2778,
#  2457,
#  781,
#  2360,
#  2701,
#  2845,
#  1412,
#  2535,
#  2097,
#  1123,
#  700,
#  1119,
#  2003,
#  2157,
#  2772,
#  97,
#  1379,
#  2454,
#  3765,
#  1800,
#  2594,
#  327,
#  2461,
#  2895,
#  3296,
#  1245,
#  2916,
#  223,
#  489,
#  3705,
#  1733,
#  1561,
#  5,
#  697,
#  2642,
#  38,
#  1918,
#  2006,
#  3413,
#  2061,
#  44,
#  3093,
#  1841,
#  501,
#  3098,
#  2186,
#  3217,
#  2534,
#  1997,
#  2743,
#  1040,
#  756,
#  1300,
#  1339,
#  492,
#  1446,
#  1155,
#  1161,
#  355,
#  3423,
#  412,
#  3870,
#  3384,
#  3667,
#  2296,
#  1242,
#  2716,
#  3218,
#  1137,
#  299,
#  2359,
#  1422,
#  2601,
#  640,
#  417,
#  557,
#  2837,
#  1635,
#  1655,
#  1583,
#  600,
#  3339,
#  369,
#  1791,
#  1609,
#  3453,
#  1968,
#  399,
#  3670,
#  3807,
#  86,
#  1873,
#  1877,
#  1229,
#  238,
#  742,
#  3126,
#  1945,
#  913,
#  1409,
#  410,
#  3351,
#  1692,
#  3401,
#  621,
#  2529,
#  469,
#  1681,
#  1940,
#  3427,
#  8,
#  2322,
#  2907,
#  3635,
#  268,
#  2442,
#  581,
#  1688,
#  2485,
#  2273,
#  2612,
#  1018,
#  1121,
#  3160,
#  2755,
#  1522,
#  3739,
#  888,
#  1112,
#  3181,
#  705,
#  622,
#  1797,
#  2805,
#  239,
#  378,
#  54,
#  1801,
#  2196,
#  82,
#  2214,
#  1549,
#  1656,
#  202,
#  3231,
#  2846,
#  1309,
#  2212,
#  3167,
#  490,
#  3365,
#  1903,
#  1702,
#  2004,
#  3204,
#  3629,
#  1629,
#  3827,
#  229,
#  1072,
#  1252,
#  559,
#  3359,
#  3418,
#  1623,
#  19,
#  828,
#  817,
#  773,
#  1375,
#  15,
#  2705,
#  2368,
#  533,
#  3353,
#  2109,
#  878,
#  910,
#  1386,
#  2649,
#  1280,
#  3199,
#  1404,
#  2218,
#  2908,
#  2495,
#  3679,
#  3614,
#  3380,
#  2860,
#  491,
#  1051,
#  2299,
#  1825,
#  2116,
#  1590,
#  1411,
#  1333,
#  482,
#  1307,
#  2291,
#  2379,
#  1056,
#  2149,
#  236,
#  3652,
#  2740,
#  1289,
#  1190,
#  2320,
#  3087,
#  2396,
#  3625,
#  929,
#  1564,
#  1922,
#  3234,
#  3400,
#  3463,
#  3875,
#  1460,
#  147,
#  3580,
#  322,
#  98,
#  3533,
#  2857,
#  1858,
#  1092,
#  1560,
#  933,
#  3322,
#  620,
#  2446,
#  1129,
#  2587,
#  2681,
#  1260,
#  3174,
#  3374,
#  2327,
#  2191,
#  1472,
#  662,
#  2584,
#  1984,
#  2341,
#  187,
#  3762,
#  1657,
#  3524,
#  2980,
#  1907,
#  2967,
#  2200,
#  2105,
#  990,
#  3461,
#  987,
#  895,
#  1057,
#  1674,
#  1154,
#  225,
#  1952,
#  1934,
#  1065,
#  256,
#  3426,
#  2922,
#  365,
#  668,
#  3197,
#  3298,
#  2613,
#  349,
#  782,
#  2712,
#  319,
#  2932,
#  ...]

# %%
file = pd.read_csv('csv.csv')

# %%
split1 = int(np.floor(.6 * a))
split2 = int(np.floor(.8 * a))
train_indices, val_indices, test_indices = indices[: split1], indices[split1: split2], indices[split2: ]

# %%
bina = []
for i in train_indices:
    bina.append(file.loc[i, 'binary'])

# %%
pd.Series(bina).value_counts()
# Out:
# 0    1475
# 1     854
# dtype: int64

# %% [markdown]
# ### new start from here

# %%
batch_size = 2
def loadData():
 
    #Create the dataset
    dataset = Dataset(csv_file = 'csv.csv', \
                     transform = transform.Compose([transform.Resize((100,100)), \
                                                    transform.ToTensor(),\
                                                   transform.Normalize((0.5, 0.5, 0.5), \
                                                                        (0.5, 0.5, 0.5))]))
    dataset_size = len(dataset)
    indices = list(range(dataset_size))
    random.shuffle(indices)
    split1 = int(np.floor(.6 * dataset_size))
    split2 = int(np.floor(.8 * dataset_size))
    train_indices, val_indices, test_indices = indices[: split1], indices[split1: split2], indices[split2: ]
 
    train_sampler = SubsetRandomSampler(train_indices)
    valid_sampler = SubsetRandomSampler(val_indices)
    test_sampler = SubsetRandomSampler(test_indices)
 
    trainloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                               sampler=train_sampler)
    valloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                           sampler=valid_sampler)
    testloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                                    sampler=test_sampler)
 
 
    return trainloader, valloader, testloader

# %%
train_loader, val_loader, test_loader = loadData()

# %%
def show_batch(images, labels):
 
        batch_size = len(images)
        im_size = images.size(0)
        grid_border_size = 3
     
        grid = make_grid(images)
        plt.imshow(grid.numpy().transpose())
        plt.title('Batch from dataloader')
        plt.show()

# %%
for imgs, (_, labels) in train_loader:
    show_batch(imgs, labels)
    break
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# for i, (images,labels) in enumerate(train_loader):
#     print(i)
#     print(images.double())
#     print(labels)
#     break

# %%
# %%time
train_model(train_loader, val_loader)
# Out:
# epoch:  0
# minibatch:  0  out of  1165
# loss:  tensor(0.7215, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1  out of  1165
# loss:  tensor(0.5512, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  2  out of  1165
# loss:  tensor(0.7472, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  3  out of  1165
# loss:  tensor(1.3740, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  4  out of  1165
# loss:  tensor(1.1392, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  5  out of  1165
# loss:  tensor(0.6442, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  6  out of  1165
# loss:  tensor(0.9334, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  7  out of  1165
# loss:  tensor(0.4273, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  8  out of  1165
# loss:  tensor(0.2954, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  9  out of  1165
# loss:  tensor(1.1335, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  10  out of  1165
# loss:  tensor(0.1414, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  11  out of  1165
# loss:  tensor(1.2567, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  12  out of  1165
# loss:  tensor(0.0873, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  13  out of  1165
# loss:  tensor(0.0754, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  14  out of  1165
# loss:  tensor(2.7779, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  15  out of  1165
# loss:  tensor(0.0725, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  16  out of  1165
# loss:  tensor(0.0780, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  17  out of  1165
# loss:  tensor(1.4799, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  18  out of  1165
# loss:  tensor(1.3415, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  19  out of  1165
# loss:  tensor(2.1334, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  20  out of  1165
# loss:  tensor(0.9308, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  21  out of  1165
# loss:  tensor(0.2843, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  22  out of  1165
# loss:  tensor(0.3920, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  23  out of  1165
# loss:  tensor(0.9800, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  24  out of  1165
# loss:  tensor(0.7641, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  25  out of  1165
# loss:  tensor(0.6067, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  26  out of  1165
# loss:  tensor(0.7736, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  27  out of  1165
# loss:  tensor(0.8943, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  28  out of  1165
# loss:  tensor(0.2838, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  29  out of  1165
# loss:  tensor(0.9167, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  30  out of  1165
# loss:  tensor(0.1969, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  31  out of  1165
# loss:  tensor(0.8407, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  32  out of  1165
# loss:  tensor(1.1573, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  33  out of  1165
# loss:  tensor(2.0863, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  34  out of  1165
# loss:  tensor(1.9469, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  35  out of  1165
# loss:  tensor(1.6501, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  36  out of  1165
# loss:  tensor(0.3039, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  37  out of  1165
# loss:  tensor(1.1209, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  38  out of  1165
# loss:  tensor(0.5806, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  39  out of  1165
# loss:  tensor(0.7161, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  40  out of  1165
# loss:  tensor(0.6698, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  41  out of  1165
# loss:  tensor(0.5500, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  42  out of  1165
# loss:  tensor(0.7944, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  43  out of  1165
# loss:  tensor(0.7423, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  44  out of  1165
# loss:  tensor(0.3865, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  45  out of  1165
# loss:  tensor(0.7869, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  46  out of  1165
# loss:  tensor(0.3200, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  47  out of  1165
# loss:  tensor(0.9318, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  48  out of  1165
# loss:  tensor(0.8560, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  49  out of  1165
# loss:  tensor(0.2547, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  50  out of  1165
# loss:  tensor(0.8397, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  51  out of  1165
# loss:  tensor(0.2489, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  52  out of  1165
# loss:  tensor(1.5386, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  53  out of  1165
# loss:  tensor(0.2658, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  54  out of  1165
# loss:  tensor(0.6811, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  55  out of  1165
# loss:  tensor(1.3351, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  56  out of  1165
# loss:  tensor(0.6531, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  57  out of  1165
# loss:  tensor(1.0070, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  58  out of  1165
# loss:  tensor(0.6343, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  59  out of  1165
# loss:  tensor(0.8326, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  60  out of  1165
# loss:  tensor(0.8027, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  61  out of  1165
# loss:  tensor(0.6960, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  62  out of  1165
# loss:  tensor(1.0413, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  63  out of  1165
# loss:  tensor(0.6436, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  64  out of  1165
# loss:  tensor(0.6587, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  65  out of  1165
# loss:  tensor(0.9538, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  66  out of  1165
# loss:  tensor(0.6898, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  67  out of  1165
# loss:  tensor(0.7621, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  68  out of  1165
# loss:  tensor(0.6323, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  69  out of  1165
# loss:  tensor(0.4966, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  70  out of  1165
# loss:  tensor(0.3680, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  71  out of  1165
# loss:  tensor(0.2659, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  72  out of  1165
# loss:  tensor(1.1565, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  73  out of  1165
# loss:  tensor(0.9630, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  74  out of  1165
# loss:  tensor(1.0281, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  75  out of  1165
# loss:  tensor(1.0978, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  76  out of  1165
# loss:  tensor(1.3902, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  77  out of  1165
# loss:  tensor(2.3607, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  78  out of  1165
# loss:  tensor(0.9738, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  79  out of  1165
# loss:  tensor(0.8046, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  80  out of  1165
# loss:  tensor(0.2464, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  81  out of  1165
# loss:  tensor(0.8588, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  82  out of  1165
# loss:  tensor(0.6830, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  83  out of  1165
# loss:  tensor(0.8031, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  84  out of  1165
# loss:  tensor(0.6318, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  85  out of  1165
# loss:  tensor(0.6982, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  86  out of  1165
# loss:  tensor(0.5196, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  87  out of  1165
# loss:  tensor(0.8289, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  88  out of  1165
# loss:  tensor(1.2673, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  89  out of  1165
# loss:  tensor(1.2258, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  90  out of  1165
# loss:  tensor(1.1657, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  91  out of  1165
# loss:  tensor(1.0457, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  92  out of  1165
# loss:  tensor(0.6572, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  93  out of  1165
# loss:  tensor(0.4558, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  94  out of  1165
# loss:  tensor(0.8941, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  95  out of  1165
# loss:  tensor(0.4954, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  96  out of  1165
# loss:  tensor(0.4229, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  97  out of  1165
# loss:  tensor(0.3738, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  98  out of  1165
# loss:  tensor(0.7330, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  99  out of  1165
# loss:  tensor(0.2889, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  100  out of  1165
# loss:  tensor(0.7400, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  101  out of  1165
# loss:  tensor(0.2294, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  102  out of  1165
# loss:  tensor(0.2153, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  103  out of  1165
# loss:  tensor(0.1594, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  104  out of  1165
# loss:  tensor(0.1512, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  105  out of  1165
# loss:  tensor(1.0446, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  106  out of  1165
# loss:  tensor(0.1084, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  107  out of  1165
# loss:  tensor(2.4321, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  108  out of  1165
# loss:  tensor(0.1205, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  109  out of  1165
# loss:  tensor(1.0405, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  110  out of  1165
# loss:  tensor(2.1206, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  111  out of  1165
# loss:  tensor(0.1753, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  112  out of  1165
# loss:  tensor(0.2257, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  113  out of  1165
# loss:  tensor(0.8514, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  114  out of  1165
# loss:  tensor(0.7216, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  115  out of  1165
# loss:  tensor(0.5148, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  116  out of  1165
# loss:  tensor(0.6577, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  117  out of  1165
# loss:  tensor(0.5608, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  118  out of  1165
# loss:  tensor(0.4884, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  119  out of  1165
# loss:  tensor(0.7936, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  120  out of  1165
# loss:  tensor(0.9083, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  121  out of  1165
# loss:  tensor(0.5527, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  122  out of  1165
# loss:  tensor(0.7818, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  123  out of  1165
# loss:  tensor(0.7903, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  124  out of  1165
# loss:  tensor(0.6481, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  125  out of  1165
# loss:  tensor(0.5926, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  126  out of  1165
# loss:  tensor(1.0399, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  127  out of  1165
# loss:  tensor(0.5806, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  128  out of  1165
# loss:  tensor(0.3531, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  129  out of  1165
# loss:  tensor(0.7475, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  130  out of  1165
# loss:  tensor(0.5200, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  131  out of  1165
# loss:  tensor(0.5556, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  132  out of  1165
# loss:  tensor(0.4986, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  133  out of  1165
# loss:  tensor(1.0865, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  134  out of  1165
# loss:  tensor(0.9856, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  135  out of  1165
# loss:  tensor(0.7920, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  136  out of  1165
# loss:  tensor(0.5773, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  137  out of  1165
# loss:  tensor(1.0911, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  138  out of  1165
# loss:  tensor(0.4328, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  139  out of  1165
# loss:  tensor(0.6609, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  140  out of  1165
# loss:  tensor(0.4676, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  141  out of  1165
# loss:  tensor(0.9673, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  142  out of  1165
# loss:  tensor(1.0630, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  143  out of  1165
# loss:  tensor(0.9777, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  144  out of  1165
# loss:  tensor(0.8568, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  145  out of  1165
# loss:  tensor(0.8039, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  146  out of  1165
# loss:  tensor(0.8610, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  147  out of  1165
# loss:  tensor(0.8756, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  148  out of  1165
# loss:  tensor(0.8156, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  149  out of  1165
# loss:  tensor(0.6844, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  150  out of  1165
# loss:  tensor(0.5632, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  151  out of  1165
# loss:  tensor(0.6601, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  152  out of  1165
# loss:  tensor(0.8198, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  153  out of  1165
# loss:  tensor(0.7537, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  154  out of  1165
# loss:  tensor(0.6369, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  155  out of  1165
# loss:  tensor(0.4164, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  156  out of  1165
# loss:  tensor(0.5884, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  157  out of  1165
# loss:  tensor(0.5409, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  158  out of  1165
# loss:  tensor(0.4975, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  159  out of  1165
# loss:  tensor(0.5847, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  160  out of  1165
# loss:  tensor(0.5174, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  161  out of  1165
# loss:  tensor(0.4046, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  162  out of  1165
# loss:  tensor(1.0484, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  163  out of  1165
# loss:  tensor(0.9869, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  164  out of  1165
# loss:  tensor(0.8750, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  165  out of  1165
# loss:  tensor(0.6595, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  166  out of  1165
# loss:  tensor(0.7083, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  167  out of  1165
# loss:  tensor(0.6186, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  168  out of  1165
# loss:  tensor(0.5656, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  169  out of  1165
# loss:  tensor(1.0307, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  170  out of  1165
# loss:  tensor(0.4238, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  171  out of  1165
# loss:  tensor(0.4098, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  172  out of  1165
# loss:  tensor(0.3174, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  173  out of  1165
# loss:  tensor(0.2482, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  174  out of  1165
# loss:  tensor(0.1926, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  175  out of  1165
# loss:  tensor(0.9045, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  176  out of  1165
# loss:  tensor(0.1432, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  177  out of  1165
# loss:  tensor(0.9243, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  178  out of  1165
# loss:  tensor(0.9174, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  179  out of  1165
# loss:  tensor(2.3648, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  180  out of  1165
# loss:  tensor(1.0179, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  181  out of  1165
# loss:  tensor(0.1762, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  182  out of  1165
# loss:  tensor(0.7012, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  183  out of  1165
# loss:  tensor(0.9328, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  184  out of  1165
# loss:  tensor(0.2861, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  185  out of  1165
# loss:  tensor(0.3634, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  186  out of  1165
# loss:  tensor(0.6438, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  187  out of  1165
# loss:  tensor(0.6772, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  188  out of  1165
# loss:  tensor(0.6708, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  189  out of  1165
# loss:  tensor(0.5538, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  190  out of  1165
# loss:  tensor(0.5804, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  191  out of  1165
# loss:  tensor(0.6451, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  192  out of  1165
# loss:  tensor(0.5336, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  193  out of  1165
# loss:  tensor(0.3695, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  194  out of  1165
# loss:  tensor(0.8973, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  195  out of  1165
# loss:  tensor(0.4964, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  196  out of  1165
# loss:  tensor(0.7133, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  197  out of  1165
# loss:  tensor(0.4463, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  198  out of  1165
# loss:  tensor(0.4811, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  199  out of  1165
# loss:  tensor(0.5243, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  200  out of  1165
# loss:  tensor(1.0499, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  201  out of  1165
# loss:  tensor(0.7469, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  202  out of  1165
# loss:  tensor(1.0425, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  203  out of  1165
# loss:  tensor(0.3186, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  204  out of  1165
# loss:  tensor(0.8202, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  205  out of  1165
# loss:  tensor(0.5007, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  206  out of  1165
# loss:  tensor(0.6438, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  207  out of  1165
# loss:  tensor(0.5788, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  208  out of  1165
# loss:  tensor(0.5948, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  209  out of  1165
# loss:  tensor(0.3693, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  210  out of  1165
# loss:  tensor(1.3896, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  211  out of  1165
# loss:  tensor(1.4682, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  212  out of  1165
# loss:  tensor(0.3132, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  213  out of  1165
# loss:  tensor(0.5882, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  214  out of  1165
# loss:  tensor(0.5124, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  215  out of  1165
# loss:  tensor(0.7485, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  216  out of  1165
# loss:  tensor(0.4747, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  217  out of  1165
# loss:  tensor(0.3575, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  218  out of  1165
# loss:  tensor(0.6257, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  219  out of  1165
# loss:  tensor(0.5797, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  220  out of  1165
# loss:  tensor(0.3812, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  221  out of  1165
# loss:  tensor(1.1434, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  222  out of  1165
# loss:  tensor(0.7178, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  223  out of  1165
# loss:  tensor(0.5695, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  224  out of  1165
# loss:  tensor(0.6628, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  225  out of  1165
# loss:  tensor(0.6147, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  226  out of  1165
# loss:  tensor(0.5253, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  227  out of  1165
# loss:  tensor(0.5394, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  228  out of  1165
# loss:  tensor(0.3360, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  229  out of  1165
# loss:  tensor(0.2743, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  230  out of  1165
# loss:  tensor(0.1990, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  231  out of  1165
# loss:  tensor(1.1380, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  232  out of  1165
# loss:  tensor(1.0593, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  233  out of  1165
# loss:  tensor(0.1199, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  234  out of  1165
# loss:  tensor(0.7219, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  235  out of  1165
# loss:  tensor(0.9167, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  236  out of  1165
# loss:  tensor(1.0484, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  237  out of  1165
# loss:  tensor(0.8397, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  238  out of  1165
# loss:  tensor(1.1573, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  239  out of  1165
# loss:  tensor(0.6712, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  240  out of  1165
# loss:  tensor(1.4430, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  241  out of  1165
# loss:  tensor(0.5469, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  242  out of  1165
# loss:  tensor(0.5516, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  243  out of  1165
# loss:  tensor(0.7579, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  244  out of  1165
# loss:  tensor(0.7122, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  245  out of  1165
# loss:  tensor(1.0437, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  246  out of  1165
# loss:  tensor(0.3645, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  247  out of  1165
# loss:  tensor(0.6876, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  248  out of  1165
# loss:  tensor(0.6276, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  249  out of  1165
# loss:  tensor(1.0030, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  250  out of  1165
# loss:  tensor(0.4809, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  251  out of  1165
# loss:  tensor(0.5434, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  252  out of  1165
# loss:  tensor(1.2090, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  253  out of  1165
# loss:  tensor(0.4320, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  254  out of  1165
# loss:  tensor(0.3942, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  255  out of  1165
# loss:  tensor(1.2587, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  256  out of  1165
# loss:  tensor(1.1778, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  257  out of  1165
# loss:  tensor(0.3989, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  258  out of  1165
# loss:  tensor(0.5290, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  259  out of  1165
# loss:  tensor(0.5665, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  260  out of  1165
# loss:  tensor(0.8175, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  261  out of  1165
# loss:  tensor(0.3724, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  262  out of  1165
# loss:  tensor(0.6879, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  263  out of  1165
# loss:  tensor(0.7016, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  264  out of  1165
# loss:  tensor(0.6646, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  265  out of  1165
# loss:  tensor(0.8693, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  266  out of  1165
# loss:  tensor(0.8836, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  267  out of  1165
# loss:  tensor(0.8514, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  268  out of  1165
# loss:  tensor(0.8379, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  269  out of  1165
# loss:  tensor(0.6441, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  270  out of  1165
# loss:  tensor(0.5187, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  271  out of  1165
# loss:  tensor(0.5971, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  272  out of  1165
# loss:  tensor(0.4253, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  273  out of  1165
# loss:  tensor(0.2832, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  274  out of  1165
# loss:  tensor(1.6681, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  275  out of  1165
# loss:  tensor(1.6390, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  276  out of  1165
# loss:  tensor(1.4759, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  277  out of  1165
# loss:  tensor(1.2521, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  278  out of  1165
# loss:  tensor(0.5546, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  279  out of  1165
# loss:  tensor(0.7406, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  280  out of  1165
# loss:  tensor(0.3313, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  281  out of  1165
# loss:  tensor(0.6108, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  282  out of  1165
# loss:  tensor(0.8741, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  283  out of  1165
# loss:  tensor(0.2390, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  284  out of  1165
# loss:  tensor(0.6777, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  285  out of  1165
# loss:  tensor(0.6099, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  286  out of  1165
# loss:  tensor(1.9830, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  287  out of  1165
# loss:  tensor(0.8521, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  288  out of  1165
# loss:  tensor(0.2094, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  289  out of  1165
# loss:  tensor(0.2516, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  290  out of  1165
# loss:  tensor(0.7323, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  291  out of  1165
# loss:  tensor(1.1380, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  292  out of  1165
# loss:  tensor(0.5886, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  293  out of  1165
# loss:  tensor(0.4681, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  294  out of  1165
# loss:  tensor(1.0205, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  295  out of  1165
# loss:  tensor(0.4752, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  296  out of  1165
# loss:  tensor(0.6373, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  297  out of  1165
# loss:  tensor(0.3729, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  298  out of  1165
# loss:  tensor(0.4931, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  299  out of  1165
# loss:  tensor(0.4445, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  300  out of  1165
# loss:  tensor(0.4623, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  301  out of  1165
# loss:  tensor(0.5829, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  302  out of  1165
# loss:  tensor(0.4155, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  303  out of  1165
# loss:  tensor(1.0494, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  304  out of  1165
# loss:  tensor(0.3574, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  305  out of  1165
# loss:  tensor(0.3210, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  306  out of  1165
# loss:  tensor(1.0964, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  307  out of  1165
# loss:  tensor(0.2819, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  308  out of  1165
# loss:  tensor(0.4500, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  309  out of  1165
# loss:  tensor(0.2678, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  310  out of  1165
# loss:  tensor(0.2744, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  311  out of  1165
# loss:  tensor(1.6082, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  312  out of  1165
# loss:  tensor(0.2649, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  313  out of  1165
# loss:  tensor(0.5383, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  314  out of  1165
# loss:  tensor(0.3353, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  315  out of  1165
# loss:  tensor(0.8755, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  316  out of  1165
# loss:  tensor(1.1895, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  317  out of  1165
# loss:  tensor(1.0213, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  318  out of  1165
# loss:  tensor(0.6219, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  319  out of  1165
# loss:  tensor(0.4758, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  320  out of  1165
# loss:  tensor(0.5360, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  321  out of  1165
# loss:  tensor(0.7230, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  322  out of  1165
# loss:  tensor(0.7025, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  323  out of  1165
# loss:  tensor(0.4809, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  324  out of  1165
# loss:  tensor(0.6457, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  325  out of  1165
# loss:  tensor(0.2694, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  326  out of  1165
# loss:  tensor(1.6101, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  327  out of  1165
# loss:  tensor(0.2809, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  328  out of  1165
# loss:  tensor(1.4567, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  329  out of  1165
# loss:  tensor(0.4888, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  330  out of  1165
# loss:  tensor(0.2134, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  331  out of  1165
# loss:  tensor(0.3144, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  332  out of  1165
# loss:  tensor(0.6924, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  333  out of  1165
# loss:  tensor(0.8250, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  334  out of  1165
# loss:  tensor(0.6653, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  335  out of  1165
# loss:  tensor(0.2979, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  336  out of  1165
# loss:  tensor(0.8301, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  337  out of  1165
# loss:  tensor(0.3395, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  338  out of  1165
# loss:  tensor(0.2421, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  339  out of  1165
# loss:  tensor(0.6736, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  340  out of  1165
# loss:  tensor(0.2058, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  341  out of  1165
# loss:  tensor(0.1226, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  342  out of  1165
# loss:  tensor(2.4039, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  343  out of  1165
# loss:  tensor(1.1654, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  344  out of  1165
# loss:  tensor(0.1017, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  345  out of  1165
# loss:  tensor(2.2414, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  346  out of  1165
# loss:  tensor(1.1586, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  347  out of  1165
# loss:  tensor(1.7574, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  348  out of  1165
# loss:  tensor(0.6642, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  349  out of  1165
# loss:  tensor(0.4617, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  350  out of  1165
# loss:  tensor(0.5736, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  351  out of  1165
# loss:  tensor(0.4595, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  352  out of  1165
# loss:  tensor(0.8230, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  353  out of  1165
# loss:  tensor(0.7625, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  354  out of  1165
# loss:  tensor(0.5162, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  355  out of  1165
# loss:  tensor(0.4027, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  356  out of  1165
# loss:  tensor(0.6631, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  357  out of  1165
# loss:  tensor(0.7512, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  358  out of  1165
# loss:  tensor(0.4172, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  359  out of  1165
# loss:  tensor(0.6448, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  360  out of  1165
# loss:  tensor(0.7277, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  361  out of  1165
# loss:  tensor(0.8980, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  362  out of  1165
# loss:  tensor(0.8936, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  363  out of  1165
# loss:  tensor(0.5002, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  364  out of  1165
# loss:  tensor(0.4834, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  365  out of  1165
# loss:  tensor(0.3868, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  366  out of  1165
# loss:  tensor(1.2978, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  367  out of  1165
# loss:  tensor(1.3060, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  368  out of  1165
# loss:  tensor(0.4111, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  369  out of  1165
# loss:  tensor(0.4631, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  370  out of  1165
# loss:  tensor(0.4219, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  371  out of  1165
# loss:  tensor(0.3833, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  372  out of  1165
# loss:  tensor(0.9525, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  373  out of  1165
# loss:  tensor(0.6789, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  374  out of  1165
# loss:  tensor(0.8793, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  375  out of  1165
# loss:  tensor(0.3587, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  376  out of  1165
# loss:  tensor(1.3588, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  377  out of  1165
# loss:  tensor(0.5281, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  378  out of  1165
# loss:  tensor(1.1370, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  379  out of  1165
# loss:  tensor(0.4691, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  380  out of  1165
# loss:  tensor(0.5505, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  381  out of  1165
# loss:  tensor(0.4264, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  382  out of  1165
# loss:  tensor(0.2075, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  383  out of  1165
# loss:  tensor(0.8251, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  384  out of  1165
# loss:  tensor(0.8434, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  385  out of  1165
# loss:  tensor(0.8041, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  386  out of  1165
# loss:  tensor(0.6367, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  387  out of  1165
# loss:  tensor(0.3943, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  388  out of  1165
# loss:  tensor(0.7244, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  389  out of  1165
# loss:  tensor(0.8177, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  390  out of  1165
# loss:  tensor(1.0693, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  391  out of  1165
# loss:  tensor(0.4644, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  392  out of  1165
# loss:  tensor(0.4276, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  393  out of  1165
# loss:  tensor(0.3863, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  394  out of  1165
# loss:  tensor(0.5558, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  395  out of  1165
# loss:  tensor(1.3349, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  396  out of  1165
# loss:  tensor(0.6245, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  397  out of  1165
# loss:  tensor(0.3693, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  398  out of  1165
# loss:  tensor(0.4241, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  399  out of  1165
# loss:  tensor(1.1810, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  400  out of  1165
# loss:  tensor(0.2523, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  401  out of  1165
# loss:  tensor(0.4330, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  402  out of  1165
# loss:  tensor(0.9122, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  403  out of  1165
# loss:  tensor(0.4152, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  404  out of  1165
# loss:  tensor(0.7547, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  405  out of  1165
# loss:  tensor(0.5235, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  406  out of  1165
# loss:  tensor(0.8338, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  407  out of  1165
# loss:  tensor(0.4613, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  408  out of  1165
# loss:  tensor(0.8072, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  409  out of  1165
# loss:  tensor(0.6965, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  410  out of  1165
# loss:  tensor(0.6231, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  411  out of  1165
# loss:  tensor(0.5435, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  412  out of  1165
# loss:  tensor(1.2681, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  413  out of  1165
# loss:  tensor(1.4296, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  414  out of  1165
# loss:  tensor(0.3014, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  415  out of  1165
# loss:  tensor(1.4108, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  416  out of  1165
# loss:  tensor(0.6449, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  417  out of  1165
# loss:  tensor(0.6046, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  418  out of  1165
# loss:  tensor(0.3964, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  419  out of  1165
# loss:  tensor(0.4149, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  420  out of  1165
# loss:  tensor(0.6454, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  421  out of  1165
# loss:  tensor(0.3546, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  422  out of  1165
# loss:  tensor(0.4771, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  423  out of  1165
# loss:  tensor(1.0791, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  424  out of  1165
# loss:  tensor(0.4950, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  425  out of  1165
# loss:  tensor(0.6563, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  426  out of  1165
# loss:  tensor(0.5926, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  427  out of  1165
# loss:  tensor(0.4002, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  428  out of  1165
# loss:  tensor(0.8427, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  429  out of  1165
# loss:  tensor(0.6067, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  430  out of  1165
# loss:  tensor(0.4759, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  431  out of  1165
# loss:  tensor(0.4594, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  432  out of  1165
# loss:  tensor(0.8601, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  433  out of  1165
# loss:  tensor(0.4921, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  434  out of  1165
# loss:  tensor(0.4418, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  435  out of  1165
# loss:  tensor(1.2352, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  436  out of  1165
# loss:  tensor(0.3530, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  437  out of  1165
# loss:  tensor(0.5667, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  438  out of  1165
# loss:  tensor(1.2988, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  439  out of  1165
# loss:  tensor(0.2880, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  440  out of  1165
# loss:  tensor(0.3984, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  441  out of  1165
# loss:  tensor(0.4390, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  442  out of  1165
# loss:  tensor(0.5799, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  443  out of  1165
# loss:  tensor(0.2940, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  444  out of  1165
# loss:  tensor(0.1997, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  445  out of  1165
# loss:  tensor(0.5265, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  446  out of  1165
# loss:  tensor(0.2798, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  447  out of  1165
# loss:  tensor(1.0169, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  448  out of  1165
# loss:  tensor(0.3262, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  449  out of  1165
# loss:  tensor(0.9313, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  450  out of  1165
# loss:  tensor(0.8519, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  451  out of  1165
# loss:  tensor(0.2316, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  452  out of  1165
# loss:  tensor(0.8458, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  453  out of  1165
# loss:  tensor(0.4621, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  454  out of  1165
# loss:  tensor(0.2208, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  455  out of  1165
# loss:  tensor(1.3433, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  456  out of  1165
# loss:  tensor(0.9901, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  457  out of  1165
# loss:  tensor(1.0118, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  458  out of  1165
# loss:  tensor(0.7099, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  459  out of  1165
# loss:  tensor(0.6773, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  460  out of  1165
# loss:  tensor(0.2672, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  461  out of  1165
# loss:  tensor(0.7925, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  462  out of  1165
# loss:  tensor(0.9094, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  463  out of  1165
# loss:  tensor(0.9135, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  464  out of  1165
# loss:  tensor(0.3836, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  465  out of  1165
# loss:  tensor(0.6966, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  466  out of  1165
# loss:  tensor(0.6788, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  467  out of  1165
# loss:  tensor(0.7070, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  468  out of  1165
# loss:  tensor(0.6654, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  469  out of  1165
# loss:  tensor(0.9004, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  470  out of  1165
# loss:  tensor(0.3999, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  471  out of  1165
# loss:  tensor(0.6251, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  472  out of  1165
# loss:  tensor(0.5482, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  473  out of  1165
# loss:  tensor(0.3137, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  474  out of  1165
# loss:  tensor(0.9579, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  475  out of  1165
# loss:  tensor(0.5265, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  476  out of  1165
# loss:  tensor(0.6596, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  477  out of  1165
# loss:  tensor(0.9587, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  478  out of  1165
# loss:  tensor(1.0187, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  479  out of  1165
# loss:  tensor(0.6657, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  480  out of  1165
# loss:  tensor(0.6332, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  481  out of  1165
# loss:  tensor(0.9742, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  482  out of  1165
# loss:  tensor(0.6162, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  483  out of  1165
# loss:  tensor(1.2039, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  484  out of  1165
# loss:  tensor(0.5410, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  485  out of  1165
# loss:  tensor(0.8125, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  486  out of  1165
# loss:  tensor(0.6672, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  487  out of  1165
# loss:  tensor(0.6280, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  488  out of  1165
# loss:  tensor(0.6368, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  489  out of  1165
# loss:  tensor(0.7371, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  490  out of  1165
# loss:  tensor(0.9897, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  491  out of  1165
# loss:  tensor(0.6178, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  492  out of  1165
# loss:  tensor(0.7604, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  493  out of  1165
# loss:  tensor(0.6974, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  494  out of  1165
# loss:  tensor(0.5888, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  495  out of  1165
# loss:  tensor(0.4737, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  496  out of  1165
# loss:  tensor(0.6212, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  497  out of  1165
# loss:  tensor(1.0977, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  498  out of  1165
# loss:  tensor(0.2697, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  499  out of  1165
# loss:  tensor(0.4909, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  500  out of  1165
# loss:  tensor(0.4707, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  501  out of  1165
# loss:  tensor(1.2519, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  502  out of  1165
# loss:  tensor(0.4044, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  503  out of  1165
# loss:  tensor(1.1652, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  504  out of  1165
# loss:  tensor(0.7381, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  505  out of  1165
# loss:  tensor(0.4623, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  506  out of  1165
# loss:  tensor(0.6360, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  507  out of  1165
# loss:  tensor(0.4785, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  508  out of  1165
# loss:  tensor(0.6417, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  509  out of  1165
# loss:  tensor(0.6480, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  510  out of  1165
# loss:  tensor(0.3917, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  511  out of  1165
# loss:  tensor(0.3721, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  512  out of  1165
# loss:  tensor(0.2585, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  513  out of  1165
# loss:  tensor(0.2788, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  514  out of  1165
# loss:  tensor(0.3588, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  515  out of  1165
# loss:  tensor(1.5766, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  516  out of  1165
# loss:  tensor(0.3384, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  517  out of  1165
# loss:  tensor(0.6250, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  518  out of  1165
# loss:  tensor(0.6070, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  519  out of  1165
# loss:  tensor(0.4877, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  520  out of  1165
# loss:  tensor(0.4292, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  521  out of  1165
# loss:  tensor(0.4486, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  522  out of  1165
# loss:  tensor(0.4077, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  523  out of  1165
# loss:  tensor(0.5520, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  524  out of  1165
# loss:  tensor(0.3844, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  525  out of  1165
# loss:  tensor(0.6999, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  526  out of  1165
# loss:  tensor(1.4859, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  527  out of  1165
# loss:  tensor(0.3646, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  528  out of  1165
# loss:  tensor(0.5655, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  529  out of  1165
# loss:  tensor(0.4402, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  530  out of  1165
# loss:  tensor(0.4830, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  531  out of  1165
# loss:  tensor(0.5058, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  532  out of  1165
# loss:  tensor(0.5132, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  533  out of  1165
# loss:  tensor(0.5060, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  534  out of  1165
# ...
#   tensor(2.0721, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.4372, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0864, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(1.9718, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0428, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1291, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0675, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1201, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0377, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0448, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0351, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0626, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0901, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1931, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0181, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.2194, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1100, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1052, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0756, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1070, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.2024, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(1.9794, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0901, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0770, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0331, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0569, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0695, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0156, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1784, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0206, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0661, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(1.9988, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0628, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0573, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.2663, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(1.9974, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1728, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0679, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0934, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1873, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0566, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1106, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0980, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0730, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0637, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0892, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0657, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0402, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0936, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0708, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1224, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1222, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0098, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0051, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0490, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0509, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1608, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0333, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0550, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0830, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1369, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0180, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1387, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1064, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0157, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0039, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1153, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1148, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0490, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0505, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0063, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0185, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0045, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0690, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.2379, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1152, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1079, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0239, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0172, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1059, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.3092, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(1.9702, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.3331, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0573, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0282, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(1.9816, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0911, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1813, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0840, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0185, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0458, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1195, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1451, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0146, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1952, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0292, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0479, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.2208, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0490, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0499, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1019, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(1.9917, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0470, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0755, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0592, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0482, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.2076, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0892, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0207, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0865, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1346, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0742, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(1.9873, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(1.9806, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1583, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1306, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1694, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(1.9747, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0446, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1227, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0259, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0616, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0510, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0895, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0512, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1862, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0545, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0589, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0568, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0453, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0617, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1956, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0422, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1510, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1197, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(1.9707, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0377, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0409, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0957, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1344, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0016, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0251, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.2646, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0189, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1654, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0688, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0719, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1089, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0992, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0099, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1247, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1463, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0966, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0948, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0199, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0286, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1930, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1814, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0385, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1118, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0067, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1632, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0970, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0644, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0700, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1469, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(1.9969, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1848, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(1.9893, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0437, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1298, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0799, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0870, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1278, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0378, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1053, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0612, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0997, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1271, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(1.9508, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0409, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1690, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1009, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0649, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0999, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0224, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.3771, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.2234, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0293, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0597, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0588, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0919, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0705, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0975, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1375, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0561, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0078, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1022, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1634, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0672, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1732, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1017, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0444, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0832, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0987, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1493, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0936, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0506, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1996, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0554, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0780, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0431, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0641, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1729, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.2027, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0021, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0351, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0433, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0761, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0175, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(1.9908, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1709, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.2193, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0148, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1917, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0895, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0535, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.3204, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0296, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0190, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1526, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0661, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0451, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0537, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0476, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1216, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0309, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0377, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1707, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0894, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0041, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0586, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1619, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1210, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.2740, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1059, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0128, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0134, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1242, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0137, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1154, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0793, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0949, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1254, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0427, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.2696, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0413, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0332, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1824, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0762, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0473, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0820, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0308, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1652, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0005, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(1.9997, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0564, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0794, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(1.9885, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0756, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1104, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1935, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0732, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0531, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0915, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0287, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0568, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(1.9925, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0566, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0061, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.1387, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0448, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0401, grad_fn=<BinaryCrossEntropyBackward>),
#   tensor(2.0032, grad_fn=<BinaryCrossEntropyBackward>)],
#  [tensor(811.6317, grad_fn=<AddBackward0>)],
#  [])

# %%
# %%time
train_loss_per_iter10, train_epoch_loss10, val_loss_per_iter10, val_epoch_loss10, val_epoch_acc10 = \
train_model(train_loader, val_loader)
# Out:
# epoch:  0
# minibatch:  0  out of  1165
# loss:  tensor(0.6587, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1  out of  1165
# loss:  tensor(0.3013, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  2  out of  1165
# loss:  tensor(0.9705, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  3  out of  1165
# loss:  tensor(0.1007, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  4  out of  1165
# loss:  tensor(1.2377, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  5  out of  1165
# loss:  tensor(1.4228, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  6  out of  1165
# loss:  tensor(2.4117, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  7  out of  1165
# loss:  tensor(0.8306, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  8  out of  1165
# loss:  tensor(0.9017, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  9  out of  1165
# loss:  tensor(0.3922, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  10  out of  1165
# loss:  tensor(0.5128, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  11  out of  1165
# loss:  tensor(0.5853, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  12  out of  1165
# loss:  tensor(0.6703, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  13  out of  1165
# loss:  tensor(0.7999, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  14  out of  1165
# loss:  tensor(0.7664, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  15  out of  1165
# loss:  tensor(0.6892, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  16  out of  1165
# loss:  tensor(0.5691, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  17  out of  1165
# loss:  tensor(0.4455, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  18  out of  1165
# loss:  tensor(0.3175, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  19  out of  1165
# loss:  tensor(0.7978, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  20  out of  1165
# loss:  tensor(0.8079, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  21  out of  1165
# loss:  tensor(2.0937, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  22  out of  1165
# loss:  tensor(0.1361, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  23  out of  1165
# loss:  tensor(1.0824, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  24  out of  1165
# loss:  tensor(1.0462, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  25  out of  1165
# loss:  tensor(0.9017, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  26  out of  1165
# loss:  tensor(0.2011, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  27  out of  1165
# loss:  tensor(1.5726, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  28  out of  1165
# loss:  tensor(0.9128, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  29  out of  1165
# loss:  tensor(0.4066, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  30  out of  1165
# loss:  tensor(0.7400, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  31  out of  1165
# loss:  tensor(0.6519, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  32  out of  1165
# loss:  tensor(0.6508, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  33  out of  1165
# loss:  tensor(0.5944, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  34  out of  1165
# loss:  tensor(0.6801, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  35  out of  1165
# loss:  tensor(1.1440, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  36  out of  1165
# loss:  tensor(0.7766, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  37  out of  1165
# loss:  tensor(1.1837, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  38  out of  1165
# loss:  tensor(1.1004, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  39  out of  1165
# loss:  tensor(0.9381, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  40  out of  1165
# loss:  tensor(0.7276, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  41  out of  1165
# loss:  tensor(0.5198, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  42  out of  1165
# loss:  tensor(1.1847, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  43  out of  1165
# loss:  tensor(1.4397, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  44  out of  1165
# loss:  tensor(0.2611, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  45  out of  1165
# loss:  tensor(0.2311, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  46  out of  1165
# loss:  tensor(1.7401, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  47  out of  1165
# loss:  tensor(0.9200, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  48  out of  1165
# loss:  tensor(0.8674, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  49  out of  1165
# loss:  tensor(0.8154, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  50  out of  1165
# loss:  tensor(0.2917, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  51  out of  1165
# loss:  tensor(0.7854, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  52  out of  1165
# loss:  tensor(0.8085, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  53  out of  1165
# loss:  tensor(1.0869, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  54  out of  1165
# loss:  tensor(0.6473, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  55  out of  1165
# loss:  tensor(0.7541, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  56  out of  1165
# loss:  tensor(0.6596, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  57  out of  1165
# loss:  tensor(1.0537, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  58  out of  1165
# loss:  tensor(1.1371, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  59  out of  1165
# loss:  tensor(0.4044, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  60  out of  1165
# loss:  tensor(1.1716, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  61  out of  1165
# loss:  tensor(1.1563, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  62  out of  1165
# loss:  tensor(0.7387, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  63  out of  1165
# loss:  tensor(0.5563, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  64  out of  1165
# loss:  tensor(0.5084, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  65  out of  1165
# loss:  tensor(0.6586, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  66  out of  1165
# loss:  tensor(0.6897, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  67  out of  1165
# loss:  tensor(0.6538, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  68  out of  1165
# loss:  tensor(0.5561, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  69  out of  1165
# loss:  tensor(0.4480, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  70  out of  1165
# loss:  tensor(1.2232, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  71  out of  1165
# loss:  tensor(0.6465, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  72  out of  1165
# loss:  tensor(0.7907, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  73  out of  1165
# loss:  tensor(0.2831, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  74  out of  1165
# loss:  tensor(0.2587, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  75  out of  1165
# loss:  tensor(1.5574, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  76  out of  1165
# loss:  tensor(0.9733, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  77  out of  1165
# loss:  tensor(0.3084, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  78  out of  1165
# loss:  tensor(0.7529, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  79  out of  1165
# loss:  tensor(0.8771, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  80  out of  1165
# loss:  tensor(0.6909, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  81  out of  1165
# loss:  tensor(1.0625, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  82  out of  1165
# loss:  tensor(0.8841, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  83  out of  1165
# loss:  tensor(0.8812, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  84  out of  1165
# loss:  tensor(0.9078, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  85  out of  1165
# loss:  tensor(0.4757, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  86  out of  1165
# loss:  tensor(0.5630, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  87  out of  1165
# loss:  tensor(0.8369, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  88  out of  1165
# loss:  tensor(0.7782, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  89  out of  1165
# loss:  tensor(1.4632, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  90  out of  1165
# loss:  tensor(0.2981, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  91  out of  1165
# loss:  tensor(0.2927, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  92  out of  1165
# loss:  tensor(1.3768, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  93  out of  1165
# loss:  tensor(1.3148, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  94  out of  1165
# loss:  tensor(0.7156, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  95  out of  1165
# loss:  tensor(0.7802, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  96  out of  1165
# loss:  tensor(0.8269, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  97  out of  1165
# loss:  tensor(0.6875, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  98  out of  1165
# loss:  tensor(0.6649, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  99  out of  1165
# loss:  tensor(0.3515, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  100  out of  1165
# loss:  tensor(0.8002, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  101  out of  1165
# loss:  tensor(1.7065, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  102  out of  1165
# loss:  tensor(0.1902, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  103  out of  1165
# loss:  tensor(0.1684, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  104  out of  1165
# loss:  tensor(0.7697, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  105  out of  1165
# loss:  tensor(0.9085, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  106  out of  1165
# loss:  tensor(2.0914, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  107  out of  1165
# loss:  tensor(0.1562, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  108  out of  1165
# loss:  tensor(1.0776, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  109  out of  1165
# loss:  tensor(0.8512, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  110  out of  1165
# loss:  tensor(0.2621, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  111  out of  1165
# loss:  tensor(0.3297, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  112  out of  1165
# loss:  tensor(0.6611, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  113  out of  1165
# loss:  tensor(0.8371, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  114  out of  1165
# loss:  tensor(0.6860, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  115  out of  1165
# loss:  tensor(0.7743, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  116  out of  1165
# loss:  tensor(0.6190, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  117  out of  1165
# loss:  tensor(0.5503, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  118  out of  1165
# loss:  tensor(0.6870, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  119  out of  1165
# loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  120  out of  1165
# loss:  tensor(0.5255, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  121  out of  1165
# loss:  tensor(0.6028, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  122  out of  1165
# loss:  tensor(0.5251, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  123  out of  1165
# loss:  tensor(1.0599, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  124  out of  1165
# loss:  tensor(1.1738, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  125  out of  1165
# loss:  tensor(1.1016, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  126  out of  1165
# loss:  tensor(0.6156, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  127  out of  1165
# loss:  tensor(0.8704, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  128  out of  1165
# loss:  tensor(0.6796, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  129  out of  1165
# loss:  tensor(0.7318, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  130  out of  1165
# loss:  tensor(0.8555, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  131  out of  1165
# loss:  tensor(0.5553, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  132  out of  1165
# loss:  tensor(0.5262, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  133  out of  1165
# loss:  tensor(0.4620, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  134  out of  1165
# loss:  tensor(0.3724, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  135  out of  1165
# loss:  tensor(0.3050, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  136  out of  1165
# loss:  tensor(0.2313, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  137  out of  1165
# loss:  tensor(0.8065, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  138  out of  1165
# loss:  tensor(1.9958, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  139  out of  1165
# loss:  tensor(0.1481, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  140  out of  1165
# loss:  tensor(0.9569, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  141  out of  1165
# loss:  tensor(0.1581, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  142  out of  1165
# loss:  tensor(0.1477, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  143  out of  1165
# loss:  tensor(0.8445, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  144  out of  1165
# loss:  tensor(0.8966, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  145  out of  1165
# loss:  tensor(0.1844, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  146  out of  1165
# loss:  tensor(0.8865, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  147  out of  1165
# loss:  tensor(1.0073, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  148  out of  1165
# loss:  tensor(0.2243, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  149  out of  1165
# loss:  tensor(0.9692, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  150  out of  1165
# loss:  tensor(0.4648, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  151  out of  1165
# loss:  tensor(0.3651, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  152  out of  1165
# loss:  tensor(0.9081, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  153  out of  1165
# loss:  tensor(0.5756, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  154  out of  1165
# loss:  tensor(0.5759, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  155  out of  1165
# loss:  tensor(0.9715, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  156  out of  1165
# loss:  tensor(0.6178, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  157  out of  1165
# loss:  tensor(0.5171, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  158  out of  1165
# loss:  tensor(0.5800, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  159  out of  1165
# loss:  tensor(0.7622, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  160  out of  1165
# loss:  tensor(0.9477, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  161  out of  1165
# loss:  tensor(0.8587, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  162  out of  1165
# loss:  tensor(0.6173, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  163  out of  1165
# loss:  tensor(0.7734, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  164  out of  1165
# loss:  tensor(0.6629, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  165  out of  1165
# loss:  tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  166  out of  1165
# loss:  tensor(0.5080, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  167  out of  1165
# loss:  tensor(0.3963, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  168  out of  1165
# loss:  tensor(0.6210, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  169  out of  1165
# loss:  tensor(0.2652, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  170  out of  1165
# loss:  tensor(0.7880, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  171  out of  1165
# loss:  tensor(0.9412, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  172  out of  1165
# loss:  tensor(0.7852, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  173  out of  1165
# loss:  tensor(1.9573, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  174  out of  1165
# loss:  tensor(1.1735, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  175  out of  1165
# loss:  tensor(0.2217, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  176  out of  1165
# loss:  tensor(0.6817, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  177  out of  1165
# loss:  tensor(1.4835, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  178  out of  1165
# loss:  tensor(0.3868, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  179  out of  1165
# loss:  tensor(1.0342, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  180  out of  1165
# loss:  tensor(0.5646, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  181  out of  1165
# loss:  tensor(0.6619, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  182  out of  1165
# loss:  tensor(0.8119, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  183  out of  1165
# loss:  tensor(0.6955, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  184  out of  1165
# loss:  tensor(0.3872, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  185  out of  1165
# loss:  tensor(0.9150, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  186  out of  1165
# loss:  tensor(0.5400, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  187  out of  1165
# loss:  tensor(0.4031, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  188  out of  1165
# loss:  tensor(0.6253, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  189  out of  1165
# loss:  tensor(0.6973, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  190  out of  1165
# loss:  tensor(0.6557, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  191  out of  1165
# loss:  tensor(0.9128, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  192  out of  1165
# loss:  tensor(0.4856, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  193  out of  1165
# loss:  tensor(0.5311, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  194  out of  1165
# loss:  tensor(0.4818, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  195  out of  1165
# loss:  tensor(0.7773, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  196  out of  1165
# loss:  tensor(0.3904, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  197  out of  1165
# loss:  tensor(0.4986, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  198  out of  1165
# loss:  tensor(0.4600, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  199  out of  1165
# loss:  tensor(0.3918, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  200  out of  1165
# loss:  tensor(0.5307, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  201  out of  1165
# loss:  tensor(0.2775, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  202  out of  1165
# loss:  tensor(1.5193, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  203  out of  1165
# loss:  tensor(0.4843, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  204  out of  1165
# loss:  tensor(0.6265, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  205  out of  1165
# loss:  tensor(1.2325, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  206  out of  1165
# loss:  tensor(0.4775, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  207  out of  1165
# loss:  tensor(0.5967, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  208  out of  1165
# loss:  tensor(0.5557, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  209  out of  1165
# loss:  tensor(0.3981, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  210  out of  1165
# loss:  tensor(0.4891, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  211  out of  1165
# loss:  tensor(0.8615, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  212  out of  1165
# loss:  tensor(0.5905, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  213  out of  1165
# loss:  tensor(0.8234, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  214  out of  1165
# loss:  tensor(0.6171, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  215  out of  1165
# loss:  tensor(0.7709, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  216  out of  1165
# loss:  tensor(0.8087, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  217  out of  1165
# loss:  tensor(0.3094, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  218  out of  1165
# loss:  tensor(0.2938, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  219  out of  1165
# loss:  tensor(0.7350, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  220  out of  1165
# loss:  tensor(0.6422, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  221  out of  1165
# loss:  tensor(0.5074, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  222  out of  1165
# loss:  tensor(0.7093, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  223  out of  1165
# loss:  tensor(0.9902, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  224  out of  1165
# loss:  tensor(0.8668, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  225  out of  1165
# loss:  tensor(0.8589, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  226  out of  1165
# loss:  tensor(0.4299, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  227  out of  1165
# loss:  tensor(0.3200, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  228  out of  1165
# loss:  tensor(0.4925, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  229  out of  1165
# loss:  tensor(1.0842, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  230  out of  1165
# loss:  tensor(0.9934, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  231  out of  1165
# loss:  tensor(0.7879, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  232  out of  1165
# loss:  tensor(0.4379, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  233  out of  1165
# loss:  tensor(0.6569, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  234  out of  1165
# loss:  tensor(0.7324, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  235  out of  1165
# loss:  tensor(0.7543, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  236  out of  1165
# loss:  tensor(0.3802, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  237  out of  1165
# loss:  tensor(0.4400, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  238  out of  1165
# loss:  tensor(0.9184, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  239  out of  1165
# loss:  tensor(0.9200, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  240  out of  1165
# loss:  tensor(0.5979, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  241  out of  1165
# loss:  tensor(0.4114, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  242  out of  1165
# loss:  tensor(0.8376, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  243  out of  1165
# loss:  tensor(0.7727, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  244  out of  1165
# loss:  tensor(0.6890, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  245  out of  1165
# loss:  tensor(0.6725, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  246  out of  1165
# loss:  tensor(0.6085, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  247  out of  1165
# loss:  tensor(0.7211, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  248  out of  1165
# loss:  tensor(0.5952, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  249  out of  1165
# loss:  tensor(0.3863, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  250  out of  1165
# loss:  tensor(0.5027, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  251  out of  1165
# loss:  tensor(0.6857, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  252  out of  1165
# loss:  tensor(0.3858, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  253  out of  1165
# loss:  tensor(0.9003, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  254  out of  1165
# loss:  tensor(0.3566, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  255  out of  1165
# loss:  tensor(0.3324, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  256  out of  1165
# loss:  tensor(0.5288, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  257  out of  1165
# loss:  tensor(0.3322, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  258  out of  1165
# loss:  tensor(0.9919, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  259  out of  1165
# loss:  tensor(0.2212, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  260  out of  1165
# loss:  tensor(0.2454, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  261  out of  1165
# loss:  tensor(0.1769, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  262  out of  1165
# loss:  tensor(2.0809, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  263  out of  1165
# loss:  tensor(0.6263, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  264  out of  1165
# loss:  tensor(0.4878, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  265  out of  1165
# loss:  tensor(0.2063, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  266  out of  1165
# loss:  tensor(1.7019, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  267  out of  1165
# loss:  tensor(0.7966, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  268  out of  1165
# loss:  tensor(0.4159, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  269  out of  1165
# loss:  tensor(0.4032, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  270  out of  1165
# loss:  tensor(0.8592, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  271  out of  1165
# loss:  tensor(0.4447, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  272  out of  1165
# loss:  tensor(0.5128, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  273  out of  1165
# loss:  tensor(0.5019, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  274  out of  1165
# loss:  tensor(0.8000, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  275  out of  1165
# loss:  tensor(1.0338, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  276  out of  1165
# loss:  tensor(1.7330, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  277  out of  1165
# loss:  tensor(1.7411, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  278  out of  1165
# loss:  tensor(1.5310, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  279  out of  1165
# loss:  tensor(1.0678, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  280  out of  1165
# loss:  tensor(0.9947, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  281  out of  1165
# loss:  tensor(0.4011, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  282  out of  1165
# loss:  tensor(0.6384, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  283  out of  1165
# loss:  tensor(1.2301, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  284  out of  1165
# loss:  tensor(0.4023, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  285  out of  1165
# loss:  tensor(1.6680, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  286  out of  1165
# loss:  tensor(0.2374, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  287  out of  1165
# loss:  tensor(0.2248, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  288  out of  1165
# loss:  tensor(0.2090, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  289  out of  1165
# loss:  tensor(0.9237, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  290  out of  1165
# loss:  tensor(0.8277, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  291  out of  1165
# loss:  tensor(1.8435, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  292  out of  1165
# loss:  tensor(0.2214, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  293  out of  1165
# loss:  tensor(0.6017, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  294  out of  1165
# loss:  tensor(0.7011, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  295  out of  1165
# loss:  tensor(0.3886, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  296  out of  1165
# loss:  tensor(0.3853, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  297  out of  1165
# loss:  tensor(0.4244, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  298  out of  1165
# loss:  tensor(1.0757, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  299  out of  1165
# loss:  tensor(0.4503, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  300  out of  1165
# loss:  tensor(0.6093, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  301  out of  1165
# loss:  tensor(0.1899, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  302  out of  1165
# loss:  tensor(0.5385, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  303  out of  1165
# loss:  tensor(0.3076, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  304  out of  1165
# loss:  tensor(0.7324, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  305  out of  1165
# loss:  tensor(0.3453, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  306  out of  1165
# loss:  tensor(0.9350, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  307  out of  1165
# loss:  tensor(0.4956, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  308  out of  1165
# loss:  tensor(0.2949, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  309  out of  1165
# loss:  tensor(0.5272, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  310  out of  1165
# loss:  tensor(0.6679, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  311  out of  1165
# loss:  tensor(0.8972, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  312  out of  1165
# loss:  tensor(0.6276, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  313  out of  1165
# loss:  tensor(0.5559, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  314  out of  1165
# loss:  tensor(0.9033, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  315  out of  1165
# loss:  tensor(0.3136, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  316  out of  1165
# loss:  tensor(0.6284, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  317  out of  1165
# loss:  tensor(0.5960, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  318  out of  1165
# loss:  tensor(0.4788, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  319  out of  1165
# loss:  tensor(0.3549, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  320  out of  1165
# loss:  tensor(0.3853, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  321  out of  1165
# loss:  tensor(0.7788, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  322  out of  1165
# loss:  tensor(0.7216, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  323  out of  1165
# loss:  tensor(0.5140, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  324  out of  1165
# loss:  tensor(0.2718, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  325  out of  1165
# loss:  tensor(0.3509, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  326  out of  1165
# loss:  tensor(0.4975, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  327  out of  1165
# loss:  tensor(0.2274, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  328  out of  1165
# loss:  tensor(1.6643, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  329  out of  1165
# loss:  tensor(0.3790, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  330  out of  1165
# loss:  tensor(0.2687, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  331  out of  1165
# loss:  tensor(0.3139, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  332  out of  1165
# loss:  tensor(0.6050, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  333  out of  1165
# loss:  tensor(0.3100, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  334  out of  1165
# loss:  tensor(0.3450, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  335  out of  1165
# loss:  tensor(0.5859, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  336  out of  1165
# loss:  tensor(0.4677, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  337  out of  1165
# loss:  tensor(0.7118, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  338  out of  1165
# loss:  tensor(0.7772, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  339  out of  1165
# loss:  tensor(0.6622, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  340  out of  1165
# loss:  tensor(0.5763, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  341  out of  1165
# loss:  tensor(0.9442, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  342  out of  1165
# loss:  tensor(0.3001, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  343  out of  1165
# loss:  tensor(0.4839, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  344  out of  1165
# loss:  tensor(0.4511, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  345  out of  1165
# loss:  tensor(0.4030, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  346  out of  1165
# loss:  tensor(1.4233, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  347  out of  1165
# loss:  tensor(0.9004, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  348  out of  1165
# loss:  tensor(0.7450, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  349  out of  1165
# loss:  tensor(0.7462, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  350  out of  1165
# loss:  tensor(0.6368, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  351  out of  1165
# loss:  tensor(0.5537, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  352  out of  1165
# loss:  tensor(0.8130, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  353  out of  1165
# loss:  tensor(0.4748, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  354  out of  1165
# loss:  tensor(0.4814, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  355  out of  1165
# loss:  tensor(0.7141, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  356  out of  1165
# loss:  tensor(0.5277, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  357  out of  1165
# loss:  tensor(0.9559, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  358  out of  1165
# loss:  tensor(0.9177, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  359  out of  1165
# loss:  tensor(0.8515, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  360  out of  1165
# loss:  tensor(0.7765, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  361  out of  1165
# loss:  tensor(0.6395, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  362  out of  1165
# loss:  tensor(0.5133, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  363  out of  1165
# loss:  tensor(1.1404, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  364  out of  1165
# loss:  tensor(0.4559, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  365  out of  1165
# loss:  tensor(0.2395, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  366  out of  1165
# loss:  tensor(1.1109, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  367  out of  1165
# loss:  tensor(1.0515, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  368  out of  1165
# loss:  tensor(0.4736, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  369  out of  1165
# loss:  tensor(0.6757, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  370  out of  1165
# loss:  tensor(0.6060, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  371  out of  1165
# loss:  tensor(0.3830, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  372  out of  1165
# loss:  tensor(1.3273, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  373  out of  1165
# loss:  tensor(0.3385, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  374  out of  1165
# loss:  tensor(0.4631, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  375  out of  1165
# loss:  tensor(0.2669, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  376  out of  1165
# loss:  tensor(0.2239, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  377  out of  1165
# loss:  tensor(0.3479, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  378  out of  1165
# loss:  tensor(0.8121, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  379  out of  1165
# loss:  tensor(0.1575, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  380  out of  1165
# loss:  tensor(0.5631, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  381  out of  1165
# loss:  tensor(0.1390, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  382  out of  1165
# loss:  tensor(1.5152, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  383  out of  1165
# loss:  tensor(0.1518, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  384  out of  1165
# loss:  tensor(0.1420, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  385  out of  1165
# loss:  tensor(0.8789, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  386  out of  1165
# loss:  tensor(2.0858, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  387  out of  1165
# loss:  tensor(0.1665, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  388  out of  1165
# loss:  tensor(0.3116, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  389  out of  1165
# loss:  tensor(0.2931, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  390  out of  1165
# loss:  tensor(1.6246, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  391  out of  1165
# loss:  tensor(0.2866, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  392  out of  1165
# loss:  tensor(0.3215, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  393  out of  1165
# loss:  tensor(0.3409, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  394  out of  1165
# loss:  tensor(0.3356, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  395  out of  1165
# loss:  tensor(1.0824, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  396  out of  1165
# loss:  tensor(0.3608, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  397  out of  1165
# loss:  tensor(0.2870, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  398  out of  1165
# loss:  tensor(1.5307, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  399  out of  1165
# loss:  tensor(0.6541, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  400  out of  1165
# loss:  tensor(0.3137, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  401  out of  1165
# loss:  tensor(0.4445, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  402  out of  1165
# loss:  tensor(0.3827, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  403  out of  1165
# loss:  tensor(0.2882, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  404  out of  1165
# loss:  tensor(0.3482, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  405  out of  1165
# loss:  tensor(0.3043, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  406  out of  1165
# loss:  tensor(0.2311, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  407  out of  1165
# loss:  tensor(0.4409, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  408  out of  1165
# loss:  tensor(0.3357, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  409  out of  1165
# loss:  tensor(0.6512, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  410  out of  1165
# loss:  tensor(0.2817, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  411  out of  1165
# loss:  tensor(0.3614, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  412  out of  1165
# loss:  tensor(1.1061, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  413  out of  1165
# loss:  tensor(0.2128, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  414  out of  1165
# loss:  tensor(0.7775, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  415  out of  1165
# loss:  tensor(0.1827, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  416  out of  1165
# loss:  tensor(0.1634, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  417  out of  1165
# loss:  tensor(0.8249, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  418  out of  1165
# loss:  tensor(0.8476, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  419  out of  1165
# loss:  tensor(1.8567, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  420  out of  1165
# loss:  tensor(0.2288, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  421  out of  1165
# loss:  tensor(0.5751, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  422  out of  1165
# loss:  tensor(0.2967, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  423  out of  1165
# loss:  tensor(0.3815, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  424  out of  1165
# loss:  tensor(0.4949, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  425  out of  1165
# loss:  tensor(0.3911, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  426  out of  1165
# loss:  tensor(0.3265, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  427  out of  1165
# loss:  tensor(0.6382, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  428  out of  1165
# loss:  tensor(0.5330, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  429  out of  1165
# loss:  tensor(0.6694, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  430  out of  1165
# loss:  tensor(0.3395, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  431  out of  1165
# loss:  tensor(0.5888, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  432  out of  1165
# loss:  tensor(0.8666, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  433  out of  1165
# loss:  tensor(0.9647, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  434  out of  1165
# loss:  tensor(0.8107, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  435  out of  1165
# loss:  tensor(0.3606, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  436  out of  1165
# loss:  tensor(0.4233, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  437  out of  1165
# loss:  tensor(0.9687, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  438  out of  1165
# loss:  tensor(1.0321, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  439  out of  1165
# loss:  tensor(0.2150, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  440  out of  1165
# loss:  tensor(0.9083, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  441  out of  1165
# loss:  tensor(0.1830, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  442  out of  1165
# loss:  tensor(0.7398, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  443  out of  1165
# loss:  tensor(0.5862, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  444  out of  1165
# loss:  tensor(0.4557, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  445  out of  1165
# loss:  tensor(0.3439, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  446  out of  1165
# loss:  tensor(0.2220, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  447  out of  1165
# loss:  tensor(1.9171, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  448  out of  1165
# loss:  tensor(1.2817, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  449  out of  1165
# loss:  tensor(0.7478, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  450  out of  1165
# loss:  tensor(0.2216, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  451  out of  1165
# loss:  tensor(0.9157, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  452  out of  1165
# loss:  tensor(0.8186, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  453  out of  1165
# loss:  tensor(0.1423, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  454  out of  1165
# loss:  tensor(0.8204, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  455  out of  1165
# loss:  tensor(0.7632, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  456  out of  1165
# loss:  tensor(1.7772, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  457  out of  1165
# loss:  tensor(0.3135, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  458  out of  1165
# loss:  tensor(1.0179, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  459  out of  1165
# loss:  tensor(1.1637, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  460  out of  1165
# loss:  tensor(0.5615, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  461  out of  1165
# loss:  tensor(0.6775, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  462  out of  1165
# loss:  tensor(0.7100, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  463  out of  1165
# loss:  tensor(0.6728, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  464  out of  1165
# loss:  tensor(1.0766, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  465  out of  1165
# loss:  tensor(0.9808, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  466  out of  1165
# loss:  tensor(0.3956, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  467  out of  1165
# loss:  tensor(0.8460, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  468  out of  1165
# loss:  tensor(0.2993, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  469  out of  1165
# loss:  tensor(0.7365, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  470  out of  1165
# loss:  tensor(0.1852, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  471  out of  1165
# loss:  tensor(0.4137, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  472  out of  1165
# loss:  tensor(1.1501, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  473  out of  1165
# loss:  tensor(0.3878, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  474  out of  1165
# loss:  tensor(1.3635, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  475  out of  1165
# loss:  tensor(0.3645, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  476  out of  1165
# loss:  tensor(0.6751, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  477  out of  1165
# loss:  tensor(0.4264, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  478  out of  1165
# loss:  tensor(0.4025, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  479  out of  1165
# loss:  tensor(0.3573, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  480  out of  1165
# loss:  tensor(0.3464, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  481  out of  1165
# loss:  tensor(0.4554, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  482  out of  1165
# loss:  tensor(0.2124, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  483  out of  1165
# loss:  tensor(0.3324, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  484  out of  1165
# loss:  tensor(0.3245, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  485  out of  1165
# loss:  tensor(0.3211, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  486  out of  1165
# loss:  tensor(0.2229, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  487  out of  1165
# loss:  tensor(1.9818, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  488  out of  1165
# loss:  tensor(0.6561, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  489  out of  1165
# loss:  tensor(1.8070, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  490  out of  1165
# loss:  tensor(0.3765, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  491  out of  1165
# loss:  tensor(0.2800, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  492  out of  1165
# loss:  tensor(0.8598, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  493  out of  1165
# loss:  tensor(0.5001, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  494  out of  1165
# loss:  tensor(0.2210, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  495  out of  1165
# loss:  tensor(0.4300, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  496  out of  1165
# loss:  tensor(0.3252, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  497  out of  1165
# loss:  tensor(0.2503, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  498  out of  1165
# loss:  tensor(0.4904, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  499  out of  1165
# loss:  tensor(0.4751, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  500  out of  1165
# loss:  tensor(0.4270, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  501  out of  1165
# loss:  tensor(0.6365, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  502  out of  1165
# loss:  tensor(0.5324, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  503  out of  1165
# loss:  tensor(0.3696, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  504  out of  1165
# loss:  tensor(0.2897, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  505  out of  1165
# loss:  tensor(0.4778, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  506  out of  1165
# loss:  tensor(1.4192, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  507  out of  1165
# loss:  tensor(1.3794, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  508  out of  1165
# loss:  tensor(0.4578, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  509  out of  1165
# loss:  tensor(0.4045, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  510  out of  1165
# loss:  tensor(0.6327, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  511  out of  1165
# loss:  tensor(0.5695, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  512  out of  1165
# loss:  tensor(0.4063, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  513  out of  1165
# loss:  tensor(0.5789, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  514  out of  1165
# loss:  tensor(0.6570, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  515  out of  1165
# loss:  tensor(0.2346, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  516  out of  1165
# loss:  tensor(0.4031, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  517  out of  1165
# loss:  tensor(0.4189, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  518  out of  1165
# loss:  tensor(0.7579, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  519  out of  1165
# loss:  tensor(0.3129, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  520  out of  1165
# loss:  tensor(0.7253, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  521  out of  1165
# loss:  tensor(0.7764, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  522  out of  1165
# loss:  tensor(0.2660, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  523  out of  1165
# loss:  tensor(0.3452, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  524  out of  1165
# loss:  tensor(0.4445, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  525  out of  1165
# loss:  tensor(0.3852, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  526  out of  1165
# loss:  tensor(0.2344, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  527  out of  1165
# loss:  tensor(0.4656, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  528  out of  1165
# loss:  tensor(0.2296, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  529  out of  1165
# loss:  tensor(0.9595, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  530  out of  1165
# loss:  tensor(0.2320, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  531  out of  1165
# loss:  tensor(0.2386, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  532  out of  1165
# loss:  tensor(1.7569, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  533  out of  1165
# loss:  tensor(1.5697, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  534  out of  1165
# ...
# minibatch:  990  out of  1165
# loss:  tensor(0.2431, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  991  out of  1165
# loss:  tensor(0.1872, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  992  out of  1165
# loss:  tensor(0.1021, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  993  out of  1165
# loss:  tensor(0.3240, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  994  out of  1165
# loss:  tensor(0.7464, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  995  out of  1165
# loss:  tensor(0.7176, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  996  out of  1165
# loss:  tensor(0.4205, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  997  out of  1165
# loss:  tensor(0.1179, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  998  out of  1165
# loss:  tensor(0.1881, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  999  out of  1165
# loss:  tensor(1.6797, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1000  out of  1165
# loss:  tensor(0.3035, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1001  out of  1165
# loss:  tensor(0.5158, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1002  out of  1165
# loss:  tensor(0.1667, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1003  out of  1165
# loss:  tensor(0.0932, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1004  out of  1165
# loss:  tensor(2.0757, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1005  out of  1165
# loss:  tensor(0.2744, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1006  out of  1165
# loss:  tensor(0.3523, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1007  out of  1165
# loss:  tensor(1.6853, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1008  out of  1165
# loss:  tensor(0.7547, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1009  out of  1165
# loss:  tensor(0.4422, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1010  out of  1165
# loss:  tensor(0.2702, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1011  out of  1165
# loss:  tensor(0.4708, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1012  out of  1165
# loss:  tensor(0.1467, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1013  out of  1165
# loss:  tensor(0.6599, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1014  out of  1165
# loss:  tensor(0.7667, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1015  out of  1165
# loss:  tensor(0.2243, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1016  out of  1165
# loss:  tensor(0.1702, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1017  out of  1165
# loss:  tensor(0.6996, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1018  out of  1165
# loss:  tensor(0.8784, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1019  out of  1165
# loss:  tensor(0.6272, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1020  out of  1165
# loss:  tensor(0.7420, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1021  out of  1165
# loss:  tensor(0.7423, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1022  out of  1165
# loss:  tensor(0.3062, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1023  out of  1165
# loss:  tensor(0.7703, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1024  out of  1165
# loss:  tensor(0.1738, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1025  out of  1165
# loss:  tensor(0.1360, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1026  out of  1165
# loss:  tensor(0.7944, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1027  out of  1165
# loss:  tensor(0.4360, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1028  out of  1165
# loss:  tensor(0.8727, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1029  out of  1165
# loss:  tensor(0.8765, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1030  out of  1165
# loss:  tensor(0.4530, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1031  out of  1165
# loss:  tensor(0.5073, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1032  out of  1165
# loss:  tensor(0.2905, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1033  out of  1165
# loss:  tensor(0.1961, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1034  out of  1165
# loss:  tensor(0.3078, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1035  out of  1165
# loss:  tensor(0.4495, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1036  out of  1165
# loss:  tensor(0.1192, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1037  out of  1165
# loss:  tensor(0.0862, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1038  out of  1165
# loss:  tensor(0.3824, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1039  out of  1165
# loss:  tensor(3.0606, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1040  out of  1165
# loss:  tensor(0.0532, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1041  out of  1165
# loss:  tensor(0.5583, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1042  out of  1165
# loss:  tensor(0.6489, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1043  out of  1165
# loss:  tensor(0.1252, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1044  out of  1165
# loss:  tensor(2.3323, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1045  out of  1165
# loss:  tensor(0.2813, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1046  out of  1165
# loss:  tensor(1.6883, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1047  out of  1165
# loss:  tensor(0.0988, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1048  out of  1165
# loss:  tensor(0.4897, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1049  out of  1165
# loss:  tensor(0.4612, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1050  out of  1165
# loss:  tensor(0.0867, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1051  out of  1165
# loss:  tensor(0.8132, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1052  out of  1165
# loss:  tensor(0.6068, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1053  out of  1165
# loss:  tensor(0.3153, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1054  out of  1165
# loss:  tensor(0.1280, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1055  out of  1165
# loss:  tensor(0.2069, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1056  out of  1165
# loss:  tensor(1.5893, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1057  out of  1165
# loss:  tensor(1.3318, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1058  out of  1165
# loss:  tensor(1.5863, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1059  out of  1165
# loss:  tensor(1.3767, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1060  out of  1165
# loss:  tensor(0.7967, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1061  out of  1165
# loss:  tensor(0.8495, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1062  out of  1165
# loss:  tensor(1.0190, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1063  out of  1165
# loss:  tensor(0.9137, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1064  out of  1165
# loss:  tensor(0.6366, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1065  out of  1165
# loss:  tensor(0.4614, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1066  out of  1165
# loss:  tensor(0.2428, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1067  out of  1165
# loss:  tensor(1.1360, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1068  out of  1165
# loss:  tensor(0.8411, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1069  out of  1165
# loss:  tensor(0.3652, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1070  out of  1165
# loss:  tensor(0.6636, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1071  out of  1165
# loss:  tensor(1.1526, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1072  out of  1165
# loss:  tensor(0.3457, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1073  out of  1165
# loss:  tensor(1.1054, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1074  out of  1165
# loss:  tensor(0.5637, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1075  out of  1165
# loss:  tensor(0.4715, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1076  out of  1165
# loss:  tensor(0.3364, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1077  out of  1165
# loss:  tensor(1.4482, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1078  out of  1165
# loss:  tensor(1.3994, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1079  out of  1165
# loss:  tensor(0.4870, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1080  out of  1165
# loss:  tensor(1.0952, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1081  out of  1165
# loss:  tensor(0.4204, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1082  out of  1165
# loss:  tensor(0.3812, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1083  out of  1165
# loss:  tensor(0.2491, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1084  out of  1165
# loss:  tensor(0.3647, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1085  out of  1165
# loss:  tensor(0.2952, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1086  out of  1165
# loss:  tensor(0.1272, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1087  out of  1165
# loss:  tensor(0.2012, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1088  out of  1165
# loss:  tensor(0.5321, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1089  out of  1165
# loss:  tensor(0.6473, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1090  out of  1165
# loss:  tensor(0.3912, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1091  out of  1165
# loss:  tensor(0.2868, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1092  out of  1165
# loss:  tensor(0.4658, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1093  out of  1165
# loss:  tensor(0.6626, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1094  out of  1165
# loss:  tensor(0.7989, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1095  out of  1165
# loss:  tensor(0.3905, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1096  out of  1165
# loss:  tensor(0.3115, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1097  out of  1165
# loss:  tensor(0.3301, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1098  out of  1165
# loss:  tensor(0.2774, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1099  out of  1165
# loss:  tensor(0.2471, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1100  out of  1165
# loss:  tensor(1.4109, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1101  out of  1165
# loss:  tensor(0.2072, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1102  out of  1165
# loss:  tensor(0.2973, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1103  out of  1165
# loss:  tensor(0.5548, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1104  out of  1165
# loss:  tensor(1.3815, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1105  out of  1165
# loss:  tensor(0.3388, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1106  out of  1165
# loss:  tensor(1.3982, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1107  out of  1165
# loss:  tensor(0.6417, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1108  out of  1165
# loss:  tensor(0.1764, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1109  out of  1165
# loss:  tensor(0.4891, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1110  out of  1165
# loss:  tensor(1.0379, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1111  out of  1165
# loss:  tensor(0.5195, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1112  out of  1165
# loss:  tensor(0.2843, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1113  out of  1165
# loss:  tensor(0.0909, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1114  out of  1165
# loss:  tensor(0.2267, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1115  out of  1165
# loss:  tensor(0.6721, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1116  out of  1165
# loss:  tensor(0.0897, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1117  out of  1165
# loss:  tensor(0.3073, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1118  out of  1165
# loss:  tensor(0.2234, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1119  out of  1165
# loss:  tensor(0.3712, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1120  out of  1165
# loss:  tensor(0.5605, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1121  out of  1165
# loss:  tensor(1.1007, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1122  out of  1165
# loss:  tensor(0.1607, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1123  out of  1165
# loss:  tensor(0.0550, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1124  out of  1165
# loss:  tensor(0.0804, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1125  out of  1165
# loss:  tensor(0.0798, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1126  out of  1165
# loss:  tensor(0.5840, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1127  out of  1165
# loss:  tensor(0.2666, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1128  out of  1165
# loss:  tensor(0.4239, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1129  out of  1165
# loss:  tensor(0.1804, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1130  out of  1165
# loss:  tensor(0.3469, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1131  out of  1165
# loss:  tensor(0.4075, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1132  out of  1165
# loss:  tensor(0.2026, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1133  out of  1165
# loss:  tensor(0.1736, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1134  out of  1165
# loss:  tensor(1.9529, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1135  out of  1165
# loss:  tensor(0.2773, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1136  out of  1165
# loss:  tensor(1.9530, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1137  out of  1165
# loss:  tensor(0.5956, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1138  out of  1165
# loss:  tensor(0.9294, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1139  out of  1165
# loss:  tensor(1.3728, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1140  out of  1165
# loss:  tensor(0.5303, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1141  out of  1165
# loss:  tensor(0.4476, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1142  out of  1165
# loss:  tensor(0.2007, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1143  out of  1165
# loss:  tensor(0.6317, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1144  out of  1165
# loss:  tensor(0.2806, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1145  out of  1165
# loss:  tensor(0.6625, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1146  out of  1165
# loss:  tensor(0.2992, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1147  out of  1165
# loss:  tensor(0.2923, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1148  out of  1165
# loss:  tensor(0.9732, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1149  out of  1165
# loss:  tensor(0.4483, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1150  out of  1165
# loss:  tensor(0.7091, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1151  out of  1165
# loss:  tensor(0.6446, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1152  out of  1165
# loss:  tensor(0.6138, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1153  out of  1165
# loss:  tensor(0.6746, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1154  out of  1165
# loss:  tensor(1.0600, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1155  out of  1165
# loss:  tensor(0.6800, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1156  out of  1165
# loss:  tensor(0.5055, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1157  out of  1165
# loss:  tensor(1.1092, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1158  out of  1165
# loss:  tensor(0.5405, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1159  out of  1165
# loss:  tensor(0.4039, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1160  out of  1165
# loss:  tensor(0.1536, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1161  out of  1165
# loss:  tensor(0.9595, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1162  out of  1165
# loss:  tensor(0.8595, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1163  out of  1165
# loss:  tensor(0.6990, grad_fn=<BinaryCrossEntropyBackward>)
# minibatch:  1164  out of  1165
# loss:  tensor(0.6438, grad_fn=<BinaryCrossEntropyBackward>)
# CPU times: user 1h 31s, sys: 2min 5s, total: 1h 2min 37s
# Wall time: 1h 7min 7s

# %%
train_epoch_loss10
# Out:
# [tensor(727.8477, grad_fn=<AddBackward0>)]

# %%
len(train_loss_per_iter10)
# Out:
# 11650

# %%
i = 1
epoch_sum = 0
train_epoch_loss10 = []
for x in train_loss_per_iter10:
    if i == 1165:
        train_epoch_loss10.append(epoch_sum)
        i=1
        epoch_sum = 0
    epoch_sum+=x
    i+=1

# %%
train_epoch_loss10
# Out:
# [tensor(751.3429, grad_fn=<AddBackward0>),
#  tensor(723.6460, grad_fn=<AddBackward0>),
#  tensor(732.3326, grad_fn=<AddBackward0>),
#  tensor(713.0840, grad_fn=<AddBackward0>),
#  tensor(724.0575, grad_fn=<AddBackward0>),
#  tensor(712.7720, grad_fn=<AddBackward0>),
#  tensor(712.9453, grad_fn=<AddBackward0>),
#  tensor(711.4532, grad_fn=<AddBackward0>),
#  tensor(699.1493, grad_fn=<AddBackward0>),
#  tensor(726.6329, grad_fn=<AddBackward0>)]

# %%
plt.plot(train_epoch_loss10)

# %%
i = 1
epoch_sum = 0
val_epoch_loss10_ = []
for x in val_loss_per_iter10:
    if i == 1165:
        val_epoch_loss10_.append(epoch_sum)
        i=1
        epoch_sum = 0
    epoch_sum+=x
    i+=1

# %%
val_epoch_loss10_
# Out:
# [tensor(758.6162, grad_fn=<AddBackward0>),
#  tensor(636.1794, grad_fn=<AddBackward0>),
#  tensor(787.7324, grad_fn=<AddBackward0>)]
